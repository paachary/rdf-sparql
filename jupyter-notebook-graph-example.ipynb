# %%
%endpoint http://localhost:9999/bigdata/sparql
%lang all
%format none
%display diagram svg withliterals
# Out:
# Endpoint set to: http://localhost:9999/bigdata/sparql
# Label preferred languages: []
# Request format: NONE
# Display: svg
# Show literals: on

# %%
prefix : <http://persondata-graph.com/>

CONSTRUCT {
    ?s ?p ?q
}
WHERE {
    ?s ?p ?q
}

# %%
prefix : <http://persondata-graph.com/>
SELECT ?s ?p ?q
WHERE {
    ?s ?p ?q
%endpoint http://localhost:9999/bigdata/sparql
%lang en
%format none
%display diagram svg}
# Out:
# <div class="krn-spql"><table><tr class=hdr><th>s</th>
# <th>p</th>
# <th>q</th></tr><tr class=odd><td class=val><a href="http://persondata-graph.com/Alex" target="_other">http://persondata-graph.com/Alex</a></td>
# <td class=val><a href="http://persondata-graph.com/born_on" target="_other">http://persondata-graph.com/born_on</a></td>
# <td class=val>1970-12-01</td></tr><tr class=even><td class=val><a href="http://persondata-graph.com/Alex" target="_other">http://persondata-graph.com/Alex</a></td>
# <td class=val><a href="http://persondata-graph.com/gender" target="_other">http://persondata-graph.com/gender</a></td>
# <td class=val>Male</td></tr><tr class=odd><td class=val><a href="http://persondata-graph.com/Alex" target="_other">http://persondata-graph.com/Alex</a></td>
# <td class=val><a href="http://persondata-graph.com/likes" target="_other">http://persondata-graph.com/likes</a></td>
# <td class=val><a href="http://persondata-graph.com/Goofy_The_Dog" target="_other">http://persondata-graph.com/Goofy_The_Dog</a></td></tr><tr class=even><td class=val><a href="http://persondata-graph.com/Alex" target="_other">http://persondata-graph.com/Alex</a></td>
# <td class=val><a href="http://persondata-graph.com/name" target="_other">http://persondata-graph.com/name</a></td>
# <td class=val>Alexender Philip</td></tr><tr class=odd><td class=val><a href="http://persondata-graph.com/Alex" target="_other">http://persondata-graph.com/Alex</a></td>
# <td class=val><a href="http://persondata-graph.com/personality_trait" target="_other">http://persondata-graph.com/personality_trait</a></td>
# <td class=val>Foodie</td></tr><tr class=even><td class=val><a href="http://persondata-graph.com/Alex" target="_other">http://persondata-graph.com/Alex</a></td>
# <td class=val><a href="http://persondata-graph.com/personality_trait" target="_other">http://persondata-graph.com/personality_trait</a></td>
# <td class=val>Hard-working</td></tr><tr class=odd><td class=val><a href="http://persondata-graph.com/Alex" target="_other">http://persondata-graph.com/Alex</a></td>
# <td class=val><a href="http://persondata-graph.com/personality_trait" target="_other">http://persondata-graph.com/personality_trait</a></td>
# <td class=val>Techie</td></tr><tr class=even><td class=val><a href="http://persondata-graph.com/Alex" target="_other">http://persondata-graph.com/Alex</a></td>
# <td class=val><a href="http://www.w3.org/1999/02/22-rdf-syntax-ns#type" target="_other">http://www.w3.org/1999/02/22-rdf-syntax-ns#type</a></td>
# <td class=val><a href="http://persondata-graph.com/Manager" target="_other">http://persondata-graph.com/Manager</a></td></tr><tr class=odd><td class=val><a href="http://persondata-graph.com/Alex" target="_other">http://persondata-graph.com/Alex</a></td>
# <td class=val><a href="http://www.w3.org/1999/02/22-rdf-syntax-ns#type" target="_other">http://www.w3.org/1999/02/22-rdf-syntax-ns#type</a></td>
# <td class=val><a href="http://persondata-graph.com/Person" target="_other">http://persondata-graph.com/Person</a></td></tr><tr class=even><td class=val><a href="http://persondata-graph.com/Goofy_The_Dog" target="_other">http://persondata-graph.com/Goofy_The_Dog</a></td>
# <td class=val><a href="http://persondata-graph.com/born_on" target="_other">http://persondata-graph.com/born_on</a></td>
# <td class=val>2019-07-04</td></tr><tr class=odd><td class=val><a href="http://persondata-graph.com/Goofy_The_Dog" target="_other">http://persondata-graph.com/Goofy_The_Dog</a></td>
# <td class=val><a href="http://persondata-graph.com/name" target="_other">http://persondata-graph.com/name</a></td>
# <td class=val>Goofy</td></tr><tr class=even><td class=val><a href="http://persondata-graph.com/Goofy_The_Dog" target="_other">http://persondata-graph.com/Goofy_The_Dog</a></td>
# <td class=val><a href="http://www.w3.org/1999/02/22-rdf-syntax-ns#type" target="_other">http://www.w3.org/1999/02/22-rdf-syntax-ns#type</a></td>
# <td class=val><a href="http://persondata-graph.com/Animal" target="_other">http://persondata-graph.com/Animal</a></td></tr><tr class=odd><td class=val><a href="http://persondata-graph.com/Mike" target="_other">http://persondata-graph.com/Mike</a></td>
# <td class=val><a href="http://persondata-graph.com/born_on" target="_other">http://persondata-graph.com/born_on</a></td>
# <td class=val>2000-01-01</td></tr><tr class=even><td class=val><a href="http://persondata-graph.com/Mike" target="_other">http://persondata-graph.com/Mike</a></td>
# <td class=val><a href="http://persondata-graph.com/friend_of" target="_other">http://persondata-graph.com/friend_of</a></td>
# <td class=val><a href="http://persondata-graph.com/Sam" target="_other">http://persondata-graph.com/Sam</a></td></tr><tr class=odd><td class=val><a href="http://persondata-graph.com/Mike" target="_other">http://persondata-graph.com/Mike</a></td>
# <td class=val><a href="http://persondata-graph.com/gender" target="_other">http://persondata-graph.com/gender</a></td>
# <td class=val>Male</td></tr><tr class=even><td class=val><a href="http://persondata-graph.com/Mike" target="_other">http://persondata-graph.com/Mike</a></td>
# <td class=val><a href="http://persondata-graph.com/has_pet" target="_other">http://persondata-graph.com/has_pet</a></td>
# <td class=val><a href="http://persondata-graph.com/Goofy_The_Dog" target="_other">http://persondata-graph.com/Goofy_The_Dog</a></td></tr><tr class=odd><td class=val><a href="http://persondata-graph.com/Mike" target="_other">http://persondata-graph.com/Mike</a></td>
# <td class=val><a href="http://persondata-graph.com/name" target="_other">http://persondata-graph.com/name</a></td>
# <td class=val>Micheal</td></tr><tr class=even><td class=val><a href="http://persondata-graph.com/Mike" target="_other">http://persondata-graph.com/Mike</a></td>
# <td class=val><a href="http://persondata-graph.com/personality_trait" target="_other">http://persondata-graph.com/personality_trait</a></td>
# <td class=val>Smart</td></tr><tr class=odd><td class=val><a href="http://persondata-graph.com/Mike" target="_other">http://persondata-graph.com/Mike</a></td>
# <td class=val><a href="http://persondata-graph.com/personality_trait" target="_other">http://persondata-graph.com/personality_trait</a></td>
# <td class=val>Techie</td></tr><tr class=even><td class=val><a href="http://persondata-graph.com/Mike" target="_other">http://persondata-graph.com/Mike</a></td>
# <td class=val><a href="http://persondata-graph.com/reports_to" target="_other">http://persondata-graph.com/reports_to</a></td>
# <td class=val><a href="http://persondata-graph.com/Tim" target="_other">http://persondata-graph.com/Tim</a></td></tr></table><div class="tinfo">Total: 39, Shown: 20</div></div>

# %%
%endpoint http://localhost:9999/bigdata/sparql
%lang all
%format none
%display diagram svg withliterals

prefix : <http://persondata-graph.com/>
CONSTRUCT {
    ?p :has_name ?name
}
WHERE {
    ?p :name ?name
}
# Out:
# Endpoint set to: http://localhost:9999/bigdata/sparql
# Label preferred languages: []
# Request format: NONE
# Display: svg
# Show literals: on

# %%
%endpoint http://localhost:9999/bigdata/sparql
%lang en
%format json
%display diagram svg  withliterals

prefix : <http://persondata-graph.com/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
SELECT ?p ?name
WHERE {
    ?p :name ?name
}
# Out:
# Endpoint set to: http://localhost:9999/bigdata/sparql
# Label preferred languages: ['en']
# Request format: JSON
# Display: svg
# Show literals: on
# {
#   "head": {
#     "vars": [
#       "p",
#       "name"
#     ]
#   },
#   "results": {
#     "bindings": [
#       {
#         "name": {
#           "type": "literal",
#           "value": "Alexender Philip"
#         },
#         "p": {
#           "type": "uri",
#           "value": "http://persondata-graph.com/Alex"
#         }
#       },
#       {
#         "name": {
#           "type": "literal",
#           "value": "Goofy"
#         },
#         "p": {
#           "type": "uri",
#           "value": "http://persondata-graph.com/Goofy_The_Dog"
#         }
#       },
#       {
#         "name": {
#           "type": "literal",
#           "value": "Micheal"
#         },
#         "p": {
#           "type": "uri",
#           "value": "http://persondata-graph.com/Mike"
#         }
#       },
#       {
#         "name": {
#           "type": "literal",
#           "value": "Samantha"
#         },
#         "p": {
#           "type": "uri",
#           "value": "http://persondata-graph.com/Sam"
#         }
#       },
#       {
#         "name": {
#           "type": "literal",
#           "value": "Timothy Dalton"
#         },
#         "p": {
#           "type": "uri",
#           "value": "http://persondata-graph.com/Tim"
#         }
#       }
#     ]
#   }
# }
